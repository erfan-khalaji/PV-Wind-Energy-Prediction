# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %mat

# %%
X = pd.read_csv('input.csv')

# %%
# Out:
# (8632, 7)

# %%
X.describe()
# Out:
#        Wind speed(m/s)  Temperature(C)     Humidity  Air Pressure  \
# count      8632.000000     8632.000000  8632.000000   8632.000000
# mean          0.407853        0.186580     0.709743      0.996968
# std           0.229877        0.074352     0.152935      0.005119
# min           0.040000       -0.010000     0.130000      0.830000
# 25%           0.220000        0.130000     0.640000      0.990000
# 50%           0.360000        0.180000     0.730000      1.000000
# 75%           0.560000        0.240000     0.830000      1.000000
# max           1.000000        1.000000     1.000000      1.000000
#
#        Wind direction  Precipitation(mm)  solar irradiation(kW/m2)
# count     8632.000000        8632.000000               8632.000000
# mean         0.182660           0.254109                  0.207660
# std          0.077407           0.101936                  0.284296
# min          0.000000           0.090000                  0.000000
# ...

# %%
sns.distplot(X['Wind speed(m/s)'])

# %%
sns.distplot(X['Temperature(C)'])

# %%
sns.distplot(X['Humidity'])

# %%
sns.distplot(X['Air Pressure'])

# %%
sns.distplot(X['Wind direction'])

# %%
sns.distplot(X['Precipitation(mm)'])

# %%
sns.distplot(X['solar irradiation(kW/m2)'])

# %%
sns.heatmap(X.corr(), annot=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('input_target.csv')
y = data.power
X = data.drop(['power','energy'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
clf = KNeighborsRegressor()
clf=clf.fit(X_train, y_train)
y_predictions = clf.predict(X_test)
print("MSE Loss Is: {}".format(mean_squared_error(y_test, y_predictions)))
# Out:
# MSE Loss Is: 5.358773989577301e-05

# %%
# list of regressors:
